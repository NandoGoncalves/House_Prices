# %%
# %matplotlib inline

import numpy as np
import pandas as pd

# %%
df = pd.read_csv("./dataset/train.csv")
df.shape
# Out:
# (1460, 81)

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df["SalePrice_label"] = 0

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolQC Fence MiscFeature MiscVal MoSold YrSold  \
# 0         Lvl    AllPub  ...    NaN   NaN         NaN       0      2   2008
# 1         Lvl    AllPub  ...    NaN   NaN         NaN       0      5   2007
# 2         Lvl    AllPub  ...    NaN   NaN         NaN       0      9   2008
# 3         Lvl    AllPub  ...    NaN   NaN         NaN       0      2   2006
# 4         Lvl    AllPub  ...    NaN   NaN         NaN       0     12   2008
#
#   SaleType  SaleCondition  SalePrice  SalePrice_label
# ...

# %%
df.loc[df['SalePrice'].between(0, 1000000), 'SalePrice_label'] = 0

# %%
df['SalePrice'].min()
# Out:
# 34900

# %%
salePrice_step = 10000

# %%
salePrice_i = 0

# %%
salePrice_max = df['SalePrice'].max()

# %%
while True:
    min_value = (salePrice_step * salePrice_i) - salePrice_step
    max_value = salePrice_step * salePrice_i
    
    df.loc[df['SalePrice'].between(min_value, max_value), 'SalePrice_label'] = salePrice_i
    print(min_value, max_value, salePrice_max)
    
    if salePrice_step * salePrice_i > salePrice_max:
        break
    salePrice_i += 1
# Out:
# -10000 0 755000
# 0 10000 755000
# 10000 20000 755000
# 20000 30000 755000
# 30000 40000 755000
# 40000 50000 755000
# 50000 60000 755000
# 60000 70000 755000
# 70000 80000 755000
# 80000 90000 755000
# 90000 100000 755000
# 100000 110000 755000
# 110000 120000 755000
# 120000 130000 755000
# 130000 140000 755000
# 140000 150000 755000
# 150000 160000 755000
# 160000 170000 755000
# 170000 180000 755000
# 180000 190000 755000
# 190000 200000 755000
# 200000 210000 755000
# 210000 220000 755000
# 220000 230000 755000
# 230000 240000 755000
# 240000 250000 755000
# 250000 260000 755000
# 260000 270000 755000
# 270000 280000 755000
# 280000 290000 755000
# 290000 300000 755000
# 300000 310000 755000
# 310000 320000 755000
# 320000 330000 755000
# 330000 340000 755000
# 340000 350000 755000
# 350000 360000 755000
# 360000 370000 755000
# 370000 380000 755000
# 380000 390000 755000
# 390000 400000 755000
# 400000 410000 755000
# 410000 420000 755000
# 420000 430000 755000
# ...

# %%
df['SalePrice_label'].unique()
# Out:
# array([21, 19, 23, 15, 26, 31, 13, 12, 35, 28, 16, 14, 10, 33, 24,  7,  5,
#        18, 17, 11,  9, 32, 25, 39, 20, 44, 22, 27, 38,  8, 42, 51, 48, 29,
#        30, 41, 37, 36, 40, 43, 34, 56, 45,  4, 46, 76,  6, 54, 49, 59, 62,
#        63, 75, 47], dtype=int64)

# %%
len(df['SalePrice_label'].unique())
# Out:
# 54

# %%
df.drop(['SalePrice'], axis=1, inplace=True)

# %%
df.to_csv('./dataset/train_label.csv', index=False)

# %%
df_l = pd.read_csv("./dataset/train_label.csv")
df_l.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice_label
# ...
