# %%
# %matplotlib inline

import numpy as np
import pandas as pd

from sklearn import neighbors
from sklearn.decomposition import PCA
from sklearn import linear_model, preprocessing
from sklearn.feature_selection import VarianceThreshold
from sklearn import model_selection
from sklearn.model_selection import train_test_split


import matplotlib.pyplot as plt
import seaborn as sns

# %%
def df_corr_columns(df, target, threshold):
    df_corr = df.corr()
    df_corr_SalePrice = df_corr[[target]]
    df_corr_SalePrice = df_corr_SalePrice.reset_index()
    df_corr_SalePrice = df_corr_SalePrice[(df_corr_SalePrice['index'] != target)]
    df_corr_SalePrice_columns = df_corr_SalePrice[(
        (df_corr_SalePrice[target] > threshold) | 
        (df_corr_SalePrice[target] < -threshold))]['index']
    return df_corr_SalePrice_columns

def separe_per_unique_threshold(df, threshold):
    dic_c_unique_len = {}
    for c in df.columns:
        dic_c_unique_len[c] = len(df[c].unique())
        #print(c, len(df_num[c].unique()))
 

    df_c_unique_len = pd.DataFrame.from_dict(dic_c_unique_len, orient="index").reset_index()
    df_c_unique_len.columns=['variable', 'count']
    return df_c_unique_len[df_c_unique_len['count'] <= 20].sort_values('count'), df_c_unique_len[df_c_unique_len['count'] > 20].sort_values('count')

def dummies(df, quantiles = 4):
    
    columns = df.columns
    for c in columns:
        
        df[c] = pd.qcut(df[c], q=quantiles, duplicates='drop') # , labels=dummies_cols
        
        df = pd.concat([df, pd.get_dummies(df[c], prefix=c)], axis=1)
        
    df.columns = [c.replace(',', '_') for c in df.columns]
    df.columns = [c.replace('(', '_') for c in df.columns]
    df.columns = [c.replace(']', '_') for c in df.columns]
    df.columns = [c.replace('.', '_') for c in df.columns]
           
        
    df.drop(columns, axis=1, inplace=True)
        
    return df

def encode_cat(df):
    
    columns = df.columns
    for c in columns:
        
        le = preprocessing.LabelEncoder()
        le.fit(df[c].unique())
        df[c] = le.transform(df[c])
        
    return df
    
    

corr_threshold = 0
dummies_quantiles = 4
variance_threshold = 0.1
unique_values_threshold = 20
pca_components = 0.999

# %%
df_train = pd.read_csv("./dataset/train.csv")

df_train_Id = df_train[['Id']]

# Outliers
df_train.drop(df_train[(df_train['YearBuilt'] < 1900) & (df_train['SalePrice'] > 250000)].index, inplace=True)
df_train.drop(df_train[(df_train['YearBuilt'] > 1980) & (df_train['SalePrice'] > 700000)].index, inplace=True)
df_train.drop(df_train[(df_train['GrLivArea'] > 4000)].index, inplace=True)

df_train_SalePrice = df_train[['SalePrice']]

df_train.drop(['Id'], axis=1, inplace=True)

df_test = pd.read_csv("./dataset/test.csv")
df_test_Id = df_test[['Id']]
df_test.drop(['Id'], axis = 1, inplace=True)

# Concat train and test to process all datas
df_train = pd.concat([df_train, df_test])

## Fill nan
df_train_num =  df_train.select_dtypes(include='number')
df_train_num.fillna(df_train_num.median(), inplace=True)


df_train_cat = df_train.select_dtypes(include='object')
df_train_cat.fillna(df_train_cat.mode().iloc[0], inplace=True)

df_train = pd.concat([df_train_num, df_train_cat], axis=1)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py:4463: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(

# %%
df_train = df_train[df_corr_columns(df_train, 'SalePrice', corr_threshold)]

df_train_cat_cols, df_train_scaled_cols = separe_per_unique_threshold(df_train, unique_values_threshold)
# transfert à la main de certaines variables pour discretisation


df_train_dummies_cols = df_train_scaled_cols[
    (df_train_scaled_cols['variable'] == 'YearBuilt') |
    (df_train_scaled_cols['variable'] == 'YearRemodAdd') |
    (df_train_scaled_cols['variable'] == 'GarageYrBlt')]

df_train_scaled_cols = df_train_scaled_cols[
    (df_train_scaled_cols['variable'] != 'YearBuilt') &
    (df_train_scaled_cols['variable'] != 'YearRemodAdd') &
    (df_train_scaled_cols['variable'] != 'GarageYrBlt')]

df_train_dummies_cols
# Out:
#         variable  count
# 6   YearRemodAdd     61
# 24   GarageYrBlt    103
# 5      YearBuilt    117

# %%
df_train_scaled_cols
# Out:
#          variable  count
# 30      3SsnPorch     31
# 14   LowQualFinSF     35
# 33        MiscVal     38
# 31    ScreenPorch    120
# 1     LotFrontage    128
# 29  EnclosedPorch    182
# 28    OpenPorchSF    248
# 9      BsmtFinSF2    272
# 27     WoodDeckSF    378
# 7      MasVnrArea    441
# 26     GarageArea    601
# 13       2ndFlrSF    629
# 8      BsmtFinSF1    989
# 11    TotalBsmtSF   1054
# 12       1stFlrSF   1078
# 10      BsmtUnfSF   1133
# 15      GrLivArea   1285
# 2         LotArea   1945

# %%
df_train_cat_cols
# Out:
#         variable  count
# 17  BsmtHalfBath      3
# 19      HalfBath      3
# 16  BsmtFullBath      4
# 21  KitchenAbvGr      4
# 18      FullBath      5
# 23    Fireplaces      5
# 35        YrSold      5
# 25    GarageCars      6
# 20  BedroomAbvGr      8
# 4    OverallCond      9
# 3    OverallQual     10
# 32      PoolArea     12
# 34        MoSold     12
# 22  TotRmsAbvGrd     14
# 0     MSSubClass     16

# %%
df_train[df_train_cat_cols['variable'].tolist()].head()
# Out:
#    BsmtHalfBath  HalfBath  BsmtFullBath  KitchenAbvGr  FullBath  Fireplaces  \
# 0           0.0         1           1.0             1         2           0
# 1           1.0         0           0.0             1         2           1
# 2           0.0         1           1.0             1         2           1
# 3           0.0         0           1.0             1         1           1
# 4           0.0         1           1.0             1         2           1
#
#    YrSold  GarageCars  BedroomAbvGr  OverallCond  OverallQual  PoolArea  \
# 0    2008         2.0             3            5            7         0
# 1    2007         2.0             3            8            6         0
# 2    2008         2.0             3            5            7         0
# 3    2006         3.0             3            5            7         0
# 4    2008         3.0             4            5            8         0
#
#    MoSold  TotRmsAbvGrd  MSSubClass
# 0       2             8          60
# 1       5             6          20
# 2       9             6          60
# 3       2             7          70
# 4      12             9          60

# %%
df_train_cat = encode_cat(df_train[df_train_cat_cols['variable'].tolist()])
# Out:
# <ipython-input-2-d6110cfa825d>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[c] = le.transform(df[c])

# %%
df_train_cat.head()
# Out:
#    BsmtHalfBath  HalfBath  BsmtFullBath  KitchenAbvGr  FullBath  Fireplaces  \
# 0             0         1             1             1         2           0
# 1             1         0             0             1         2           1
# 2             0         1             1             1         2           1
# 3             0         0             1             1         1           1
# 4             0         1             1             1         2           1
#
#    YrSold  GarageCars  BedroomAbvGr  OverallCond  OverallQual  PoolArea  \
# 0       2           2             3            4            6         0
# 1       1           2             3            7            5         0
# 2       2           2             3            4            6         0
# 3       0           3             3            4            6         0
# 4       2           3             4            4            7         0
#
#    MoSold  TotRmsAbvGrd  MSSubClass
# 0       1             6           5
# 1       4             4           0
# 2       8             4           5
# 3       1             5           6
# 4      11             7           5

# %%
df_train_dummies = dummies(df_train[df_train_dummies_cols['variable'].tolist()])
# Out:
# <ipython-input-2-d6110cfa825d>:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[c] = pd.qcut(df[c], q=quantiles, duplicates='drop') # , labels=dummies_cols

# %%
df_train_dummies.head()
# Out:
#    YearRemodAdd__1949_999_ 1965_0_  YearRemodAdd__1965_0_ 1993_0_  \
# 0                                0                              0
# 1                                0                              1
# 2                                0                              0
# 3                                0                              1
# 4                                0                              0
#
#    YearRemodAdd__1993_0_ 2004_0_  YearRemodAdd__2004_0_ 2010_0_  \
# 0                              1                              0
# 1                              0                              0
# 2                              1                              0
# 3                              0                              0
# 4                              1                              0
#
#    GarageYrBlt__1894_999_ 1961_0_  GarageYrBlt__1961_0_ 1979_0_  \
# 0                               0                             0
# 1                               0                             1
# 2                               0                             0
# 3                               0                             0
# 4                               0                             0
#
#    GarageYrBlt__1979_0_ 2001_0_  GarageYrBlt__2001_0_ 2207_0_  \
# 0                             0                             1
# 1                             0                             0
# 2                             1                             0
# 3                             1                             0
# 4                             1                             0
#
#    YearBuilt__1871_999_ 1954_0_  YearBuilt__1954_0_ 1973_0_  \
# 0                             0                           0
# 1                             0                           0
# 2                             0                           0
# 3                             1                           0
# 4                             0                           0
#
#    YearBuilt__1973_0_ 2001_0_  YearBuilt__2001_0_ 2010_0_
# 0                           0                           1
# 1                           1                           0
# 2                           1                           0
# 3                           0                           0
# 4                           1                           0

# %%
# Scaled
df_train_scaled = df_train[df_train_scaled_cols['variable'].tolist()]

scaler = preprocessing.StandardScaler().fit(df_train_scaled)
df_train_scaled[df_train_scaled.columns] = pd.DataFrame(scaler.transform(df_train_scaled), index=df_train_scaled.index)

df_train_scaled.head()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:3191: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
#    3SsnPorch  LowQualFinSF   MiscVal  ScreenPorch  LotFrontage  EnclosedPorch  \
# 0  -0.103474     -0.099696 -0.089716    -0.286275    -0.189292      -0.360063
# 1  -0.103474     -0.099696 -0.089716    -0.286275     0.533844      -0.360063
# 2  -0.103474     -0.099696 -0.089716    -0.286275    -0.044665      -0.360063
# 3  -0.103474     -0.099696 -0.089716    -0.286275    -0.430338       3.892679
# 4  -0.103474     -0.099696 -0.089716    -0.286275     0.726680      -0.360063
#
#    OpenPorchSF  BsmtFinSF2  WoodDeckSF  MasVnrArea  GarageArea  2ndFlrSF  \
# 0     0.209400   -0.293462   -0.738938    0.538113    0.356719  1.227949
# 1    -0.707690   -0.293462    1.617934   -0.569040   -0.054343 -0.785512
# 2    -0.076251   -0.293462   -0.738938    0.346056    0.636989  1.256241
# 3    -0.181491   -0.293462   -0.738938   -0.569040    0.795808  0.996896
# 4     0.555188   -0.293462    0.779584    1.408018    1.702013  1.697128
#
#    BsmtFinSF1  TotalBsmtSF  1stFlrSF  BsmtUnfSF  GrLivArea   LotArea
# 0    0.603810    -0.448980 -0.782325  -0.932996   0.443045 -0.214575
# 1    1.218183     0.500077  0.275230  -0.627798  -0.475947 -0.067230
# 2    0.106891    -0.299375 -0.615616  -0.286158   0.598945  0.144178
# 3   -0.502964    -0.682738 -0.508819  -0.044732   0.457404 -0.073636
# 4    0.488616     0.226581 -0.029533  -0.158612   1.444089  0.529839

# %%
df_train = pd.concat([df_train_cat, df_train_scaled, df_train_dummies], axis=1)
df_train.shape
# Out:
# (2911, 45)

# %%
df_test = df_train.tail(1459) 
df_train = df_train.head(df_train_SalePrice.shape[0]) # shape minus outliers 

print(df_train.shape, df_test.shape)
# Out:
# (1452, 45) (1459, 45)

# %%
target = df_train_SalePrice
data = df_train

# %%
# centrer la distribution de la cible
target = np.log1p(target['SalePrice'])

# %%
X_train, X_test, y_train, y_test = train_test_split(data, target, test_size = 0.3, random_state = 66)

# %%
import xgboost
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error
print(xgboost.__version__)
# Out:
# 1.5.2

# %%
# create an xgboost regression model
#model_xgbr = XGBRegressor()

# Instantiation
'''
xgb_r = XGBRegressor(objective ='reg:squarederror', learning_rate=0.3, subsample=0.8, colsample_bytree=1, gamma=0.1,
                     max_depth=4, 
                  n_estimators = 830, seed = 123)
'''

xgb_r = xgb.XGBRegressor(colsample_bytree=0.4603, gamma=0.0468, 
                             learning_rate=0.05, max_depth=3, 
                             min_child_weight=1.7817, n_estimators=2200,
                             reg_alpha=0.4640, reg_lambda=0.8571,
                             subsample=0.5213, silent=1,
                             random_state =7, nthread = -1)

  
# Fitting the model
eval_set = [(X_test, y_test)]
xgb_r.fit(X_train, y_train, eval_metric="rmse", eval_set=eval_set, verbose=True)
  
# Predict the model
pred = xgb_r.predict(X_test)
  
# RMSE Computation
rmse = np.sqrt(mean_squared_error(y_test, pred))
print("RMSE : % f" %(rmse))
# Out:
# [0]	validation_0-rmse:8.07062
# [1]	validation_0-rmse:5.65678
# [2]	validation_0-rmse:3.96779
# [3]	validation_0-rmse:2.78527
# [4]	validation_0-rmse:1.96198
# [5]	validation_0-rmse:1.38555
# [6]	validation_0-rmse:0.98338
# [7]	validation_0-rmse:0.70253
# [8]	validation_0-rmse:0.51079
# [9]	validation_0-rmse:0.37983
# [10]	validation_0-rmse:0.29284
# [11]	validation_0-rmse:0.23592
# [12]	validation_0-rmse:0.20245
# [13]	validation_0-rmse:0.18271
# [14]	validation_0-rmse:0.16882
# [15]	validation_0-rmse:0.16099
# [16]	validation_0-rmse:0.15640
# [17]	validation_0-rmse:0.15324
# [18]	validation_0-rmse:0.15236
# [19]	validation_0-rmse:0.15182
# [20]	validation_0-rmse:0.15162
# [21]	validation_0-rmse:0.15083
# [22]	validation_0-rmse:0.14975
# [23]	validation_0-rmse:0.14932
# [24]	validation_0-rmse:0.14866
# [25]	validation_0-rmse:0.14825
# [26]	validation_0-rmse:0.14769
# [27]	validation_0-rmse:0.14769
# [28]	validation_0-rmse:0.14771
# [29]	validation_0-rmse:0.14771
# [30]	validation_0-rmse:0.14631
# [31]	validation_0-rmse:0.14632
# [32]	validation_0-rmse:0.14573
# [33]	validation_0-rmse:0.14573
# [34]	validation_0-rmse:0.14573
# [35]	validation_0-rmse:0.14577
# [36]	validation_0-rmse:0.14577
# [37]	validation_0-rmse:0.14578
# [38]	validation_0-rmse:0.14577
# [39]	validation_0-rmse:0.14578
# [40]	validation_0-rmse:0.14562
# [41]	validation_0-rmse:0.14550
# [42]	validation_0-rmse:0.14523
# [43]	validation_0-rmse:0.14524
# [44]	validation_0-rmse:0.14525
# [45]	validation_0-rmse:0.14524
# [46]	validation_0-rmse:0.14522
# [47]	validation_0-rmse:0.14522
# [48]	validation_0-rmse:0.14521
# [49]	validation_0-rmse:0.14521
# [50]	validation_0-rmse:0.14521
# [51]	validation_0-rmse:0.14520
# [52]	validation_0-rmse:0.14521
# [53]	validation_0-rmse:0.14470
# [54]	validation_0-rmse:0.14470
# [55]	validation_0-rmse:0.14477
# [56]	validation_0-rmse:0.14477
# [57]	validation_0-rmse:0.14477
# [58]	validation_0-rmse:0.14476
# [59]	validation_0-rmse:0.14476
# [60]	validation_0-rmse:0.14477
# [61]	validation_0-rmse:0.14473
# [62]	validation_0-rmse:0.14474
# [63]	validation_0-rmse:0.14443
# [64]	validation_0-rmse:0.14418
# [65]	validation_0-rmse:0.14418
# [66]	validation_0-rmse:0.14418
# [67]	validation_0-rmse:0.14417
# [68]	validation_0-rmse:0.14417
# [69]	validation_0-rmse:0.14418
# [70]	validation_0-rmse:0.14418
# [71]	validation_0-rmse:0.14418
# [72]	validation_0-rmse:0.14418
# [73]	validation_0-rmse:0.14418
# [74]	validation_0-rmse:0.14418
# [75]	validation_0-rmse:0.14388
# [76]	validation_0-rmse:0.14388
# [77]	validation_0-rmse:0.14388
# [78]	validation_0-rmse:0.14388
# [79]	validation_0-rmse:0.14388
# [80]	validation_0-rmse:0.14389
# [81]	validation_0-rmse:0.14388
# [82]	validation_0-rmse:0.14388
# [83]	validation_0-rmse:0.14388
# [84]	validation_0-rmse:0.14388
# [85]	validation_0-rmse:0.14388
# [86]	validation_0-rmse:0.14389
# [87]	validation_0-rmse:0.14388
# [88]	validation_0-rmse:0.14388
# [89]	validation_0-rmse:0.14388
# [90]	validation_0-rmse:0.14388
# [91]	validation_0-rmse:0.14389
# [92]	validation_0-rmse:0.14388
# [93]	validation_0-rmse:0.14389
# [94]	validation_0-rmse:0.14388
# [95]	validation_0-rmse:0.14388
# [96]	validation_0-rmse:0.14388
# [97]	validation_0-rmse:0.14388
# [98]	validation_0-rmse:0.14388
# [99]	validation_0-rmse:0.14388
# [100]	validation_0-rmse:0.14388
# [101]	validation_0-rmse:0.14388
# [102]	validation_0-rmse:0.14388
# [103]	validation_0-rmse:0.14388
# [104]	validation_0-rmse:0.14389
# [105]	validation_0-rmse:0.14388
# [106]	validation_0-rmse:0.14389
# [107]	validation_0-rmse:0.14388
# [108]	validation_0-rmse:0.14388
# [109]	validation_0-rmse:0.14388
# [110]	validation_0-rmse:0.14388
# [111]	validation_0-rmse:0.14388
# [112]	validation_0-rmse:0.14388
# [113]	validation_0-rmse:0.14389
# [114]	validation_0-rmse:0.14395
# [115]	validation_0-rmse:0.14396
# [116]	validation_0-rmse:0.14395
# [117]	validation_0-rmse:0.14395
# [118]	validation_0-rmse:0.14395
# [119]	validation_0-rmse:0.14395
# [120]	validation_0-rmse:0.14396
# [121]	validation_0-rmse:0.14395
# [122]	validation_0-rmse:0.14395
# [123]	validation_0-rmse:0.14395
# [124]	validation_0-rmse:0.14396
# [125]	validation_0-rmse:0.14359
# [126]	validation_0-rmse:0.14359
# [127]	validation_0-rmse:0.14358
# [128]	validation_0-rmse:0.14358
# [129]	validation_0-rmse:0.14358
# [130]	validation_0-rmse:0.14358
# [131]	validation_0-rmse:0.14358
# [132]	validation_0-rmse:0.14358
# [133]	validation_0-rmse:0.14358
# [134]	validation_0-rmse:0.14358
# [135]	validation_0-rmse:0.14358
# [136]	validation_0-rmse:0.14358
# [137]	validation_0-rmse:0.14358
# [138]	validation_0-rmse:0.14326
# [139]	validation_0-rmse:0.14326
# [140]	validation_0-rmse:0.14327
# [141]	validation_0-rmse:0.14327
# [142]	validation_0-rmse:0.14326
# [143]	validation_0-rmse:0.14327
# [144]	validation_0-rmse:0.14326
# [145]	validation_0-rmse:0.14325
# [146]	validation_0-rmse:0.14326
# [147]	validation_0-rmse:0.14325
# [148]	validation_0-rmse:0.14325
# [149]	validation_0-rmse:0.14325
# [150]	validation_0-rmse:0.14325
# [151]	validation_0-rmse:0.14326
# [152]	validation_0-rmse:0.14325
# [153]	validation_0-rmse:0.14326
# [154]	validation_0-rmse:0.14326
# [155]	validation_0-rmse:0.14325
# [156]	validation_0-rmse:0.14325
# [157]	validation_0-rmse:0.14325
# [158]	validation_0-rmse:0.14325
# [159]	validation_0-rmse:0.14323
# [160]	validation_0-rmse:0.14323
# [161]	validation_0-rmse:0.14323
# [162]	validation_0-rmse:0.14323
# [163]	validation_0-rmse:0.14323
# [164]	validation_0-rmse:0.14323
# [165]	validation_0-rmse:0.14323
# [166]	validation_0-rmse:0.14324
# [167]	validation_0-rmse:0.14280
# [168]	validation_0-rmse:0.14279
# [169]	validation_0-rmse:0.14279
# [170]	validation_0-rmse:0.14283
# [171]	validation_0-rmse:0.14283
# [172]	validation_0-rmse:0.14280
# [173]	validation_0-rmse:0.14280
# [174]	validation_0-rmse:0.14280
# [175]	validation_0-rmse:0.14280
# [176]	validation_0-rmse:0.14280
# [177]	validation_0-rmse:0.14280
# [178]	validation_0-rmse:0.14279
# [179]	validation_0-rmse:0.14279
# [180]	validation_0-rmse:0.14280
# [181]	validation_0-rmse:0.14279
# [182]	validation_0-rmse:0.14286
# [183]	validation_0-rmse:0.14286
# [184]	validation_0-rmse:0.14286
# [185]	validation_0-rmse:0.14286
# [186]	validation_0-rmse:0.14286
# [187]	validation_0-rmse:0.14286
# [188]	validation_0-rmse:0.14287
# [189]	validation_0-rmse:0.14286
# [190]	validation_0-rmse:0.14286
# [191]	validation_0-rmse:0.14286
# [192]	validation_0-rmse:0.14286
# [193]	validation_0-rmse:0.14286
# [194]	validation_0-rmse:0.14286
# [195]	validation_0-rmse:0.14286
# [196]	validation_0-rmse:0.14286
# [197]	validation_0-rmse:0.14286
# [198]	validation_0-rmse:0.14286
# [199]	validation_0-rmse:0.14286
# [200]	validation_0-rmse:0.14286
# [201]	validation_0-rmse:0.14286
# [202]	validation_0-rmse:0.14257
# [203]	validation_0-rmse:0.14257
# [204]	validation_0-rmse:0.14257
# [205]	validation_0-rmse:0.14257
# [206]	validation_0-rmse:0.14257
# [207]	validation_0-rmse:0.14257
# [208]	validation_0-rmse:0.14258
# [209]	validation_0-rmse:0.14258
# [210]	validation_0-rmse:0.14257
# [211]	validation_0-rmse:0.14257
# [212]	validation_0-rmse:0.14257
# [213]	validation_0-rmse:0.14257
# [214]	validation_0-rmse:0.14257
# [215]	validation_0-rmse:0.14257
# [216]	validation_0-rmse:0.14257
# [217]	validation_0-rmse:0.14257
# [218]	validation_0-rmse:0.14258
# [219]	validation_0-rmse:0.14257
# [220]	validation_0-rmse:0.14257
# [221]	validation_0-rmse:0.14257
# [222]	validation_0-rmse:0.14257
# [223]	validation_0-rmse:0.14257
# [224]	validation_0-rmse:0.14257
# [225]	validation_0-rmse:0.14257
# [226]	validation_0-rmse:0.14257
# [227]	validation_0-rmse:0.14257
# [228]	validation_0-rmse:0.14257
# [229]	validation_0-rmse:0.14257
# [230]	validation_0-rmse:0.14257
# [231]	validation_0-rmse:0.14257
# [232]	validation_0-rmse:0.14257
# [233]	validation_0-rmse:0.14257
# [234]	validation_0-rmse:0.14257
# [235]	validation_0-rmse:0.14257
# [236]	validation_0-rmse:0.14257
# [237]	validation_0-rmse:0.14257
# [238]	validation_0-rmse:0.14257
# [239]	validation_0-rmse:0.14257
# [240]	validation_0-rmse:0.14257
# [241]	validation_0-rmse:0.14257
# [242]	validation_0-rmse:0.14257
# [243]	validation_0-rmse:0.14296
# [244]	validation_0-rmse:0.14297
# [245]	validation_0-rmse:0.14297
# [246]	validation_0-rmse:0.14296
# [247]	validation_0-rmse:0.14296
# [248]	validation_0-rmse:0.14296
# [249]	validation_0-rmse:0.14297
# [250]	validation_0-rmse:0.14296
# [251]	validation_0-rmse:0.14297
# [252]	validation_0-rmse:0.14296
# [253]	validation_0-rmse:0.14296
# [254]	validation_0-rmse:0.14296
# [255]	validation_0-rmse:0.14296
# [256]	validation_0-rmse:0.14296
# [257]	validation_0-rmse:0.14296
# [258]	validation_0-rmse:0.14297
# [259]	validation_0-rmse:0.14297
# [260]	validation_0-rmse:0.14296
# [261]	validation_0-rmse:0.14297
# [262]	validation_0-rmse:0.14297
# [263]	validation_0-rmse:0.14296
# [264]	validation_0-rmse:0.14297
# [265]	validation_0-rmse:0.14296
# [266]	validation_0-rmse:0.14297
# [267]	validation_0-rmse:0.14297
# [268]	validation_0-rmse:0.14297
# [269]	validation_0-rmse:0.14297
# [270]	validation_0-rmse:0.14297
# [271]	validation_0-rmse:0.14296
# [272]	validation_0-rmse:0.14296
# [273]	validation_0-rmse:0.14296
# [274]	validation_0-rmse:0.14297
# [275]	validation_0-rmse:0.14296
# [276]	validation_0-rmse:0.14296
# [277]	validation_0-rmse:0.14296
# [278]	validation_0-rmse:0.14297
# [279]	validation_0-rmse:0.14297
# [280]	validation_0-rmse:0.14297
# [281]	validation_0-rmse:0.14279
# [282]	validation_0-rmse:0.14279
# [283]	validation_0-rmse:0.14279
# [284]	validation_0-rmse:0.14279
# [285]	validation_0-rmse:0.14279
# [286]	validation_0-rmse:0.14279
# [287]	validation_0-rmse:0.14279
# [288]	validation_0-rmse:0.14279
# [289]	validation_0-rmse:0.14279
# [290]	validation_0-rmse:0.14279
# [291]	validation_0-rmse:0.14279
# [292]	validation_0-rmse:0.14279
# [293]	validation_0-rmse:0.14279
# [294]	validation_0-rmse:0.14279
# [295]	validation_0-rmse:0.14279
# [296]	validation_0-rmse:0.14279
# [297]	validation_0-rmse:0.14279
# [298]	validation_0-rmse:0.14279
# [299]	validation_0-rmse:0.14279
# [300]	validation_0-rmse:0.14279
# [301]	validation_0-rmse:0.14279
# [302]	validation_0-rmse:0.14279
# [303]	validation_0-rmse:0.14279
# [304]	validation_0-rmse:0.14279
# [305]	validation_0-rmse:0.14279
# [306]	validation_0-rmse:0.14279
# [307]	validation_0-rmse:0.14279
# [308]	validation_0-rmse:0.14279
# [309]	validation_0-rmse:0.14279
# [310]	validation_0-rmse:0.14279
# [311]	validation_0-rmse:0.14279
# [312]	validation_0-rmse:0.14279
# [313]	validation_0-rmse:0.14279
# [314]	validation_0-rmse:0.14279
# [315]	validation_0-rmse:0.14279
# [316]	validation_0-rmse:0.14279
# [317]	validation_0-rmse:0.14279
# [318]	validation_0-rmse:0.14279
# [319]	validation_0-rmse:0.14279
# [320]	validation_0-rmse:0.14279
# [321]	validation_0-rmse:0.14279
# [322]	validation_0-rmse:0.14279
# [323]	validation_0-rmse:0.14279
# [324]	validation_0-rmse:0.14279
# [325]	validation_0-rmse:0.14279
# [326]	validation_0-rmse:0.14279
# [327]	validation_0-rmse:0.14279
# [328]	validation_0-rmse:0.14279
# [329]	validation_0-rmse:0.14279
# [330]	validation_0-rmse:0.14279
# [331]	validation_0-rmse:0.14279
# [332]	validation_0-rmse:0.14279
# [333]	validation_0-rmse:0.14279
# [334]	validation_0-rmse:0.14279
# [335]	validation_0-rmse:0.14279
# [336]	validation_0-rmse:0.14264
# [337]	validation_0-rmse:0.14264
# [338]	validation_0-rmse:0.14264
# [339]	validation_0-rmse:0.14264
# [340]	validation_0-rmse:0.14264
# [341]	validation_0-rmse:0.14264
# [342]	validation_0-rmse:0.14264
# [343]	validation_0-rmse:0.14264
# [344]	validation_0-rmse:0.14264
# [345]	validation_0-rmse:0.14264
# [346]	validation_0-rmse:0.14264
# [347]	validation_0-rmse:0.14264
# [348]	validation_0-rmse:0.14264
# [349]	validation_0-rmse:0.14264
# [350]	validation_0-rmse:0.14265
# [351]	validation_0-rmse:0.14264
# [352]	validation_0-rmse:0.14264
# [353]	validation_0-rmse:0.14264
# [354]	validation_0-rmse:0.14264
# [355]	validation_0-rmse:0.14258
# [356]	validation_0-rmse:0.14258
# [357]	validation_0-rmse:0.14258
# [358]	validation_0-rmse:0.14258
# [359]	validation_0-rmse:0.14258
# [360]	validation_0-rmse:0.14258
# [361]	validation_0-rmse:0.14258
# [362]	validation_0-rmse:0.14258
# [363]	validation_0-rmse:0.14258
# [364]	validation_0-rmse:0.14258
# [365]	validation_0-rmse:0.14258
# [366]	validation_0-rmse:0.14258
# [367]	validation_0-rmse:0.14258
# [368]	validation_0-rmse:0.14258
# [369]	validation_0-rmse:0.14259
# [370]	validation_0-rmse:0.14259
# [371]	validation_0-rmse:0.14259
# [372]	validation_0-rmse:0.14258
# [373]	validation_0-rmse:0.14259
# [374]	validation_0-rmse:0.14259
# [375]	validation_0-rmse:0.14259
# [376]	validation_0-rmse:0.14258
# [377]	validation_0-rmse:0.14258
# [378]	validation_0-rmse:0.14259
# [379]	validation_0-rmse:0.14259
# [380]	validation_0-rmse:0.14259
# [381]	validation_0-rmse:0.14259
# [382]	validation_0-rmse:0.14258
# [383]	validation_0-rmse:0.14258
# [384]	validation_0-rmse:0.14259
# [385]	validation_0-rmse:0.14259
# [386]	validation_0-rmse:0.14259
# [387]	validation_0-rmse:0.14258
# [388]	validation_0-rmse:0.14253
# [389]	validation_0-rmse:0.14254
# [390]	validation_0-rmse:0.14253
# [391]	validation_0-rmse:0.14253
# [392]	validation_0-rmse:0.14253
# [393]	validation_0-rmse:0.14254
# [394]	validation_0-rmse:0.14254
# [395]	validation_0-rmse:0.14254
# [396]	validation_0-rmse:0.14254
# [397]	validation_0-rmse:0.14254
# [398]	validation_0-rmse:0.14254
# [399]	validation_0-rmse:0.14254
# [400]	validation_0-rmse:0.14254
# [401]	validation_0-rmse:0.14254
# [402]	validation_0-rmse:0.14253
# [403]	validation_0-rmse:0.14253
# [404]	validation_0-rmse:0.14254
# [405]	validation_0-rmse:0.14254
# [406]	validation_0-rmse:0.14254
# [407]	validation_0-rmse:0.14254
# [408]	validation_0-rmse:0.14254
# [409]	validation_0-rmse:0.14254
# [410]	validation_0-rmse:0.14254
# [411]	validation_0-rmse:0.14254
# [412]	validation_0-rmse:0.14254
# [413]	validation_0-rmse:0.14254
# [414]	validation_0-rmse:0.14254
# [415]	validation_0-rmse:0.14254
# [416]	validation_0-rmse:0.14254
# [417]	validation_0-rmse:0.14254
# [418]	validation_0-rmse:0.14254
# [419]	validation_0-rmse:0.14254
# [420]	validation_0-rmse:0.14253
# [421]	validation_0-rmse:0.14254
# [422]	validation_0-rmse:0.14253
# [423]	validation_0-rmse:0.14253
# [424]	validation_0-rmse:0.14254
# [425]	validation_0-rmse:0.14254
# [426]	validation_0-rmse:0.14254
# [427]	validation_0-rmse:0.14253
# [428]	validation_0-rmse:0.14254
# [429]	validation_0-rmse:0.14254
# [430]	validation_0-rmse:0.14254
# [431]	validation_0-rmse:0.14254
# [432]	validation_0-rmse:0.14254
# [433]	validation_0-rmse:0.14254
# [434]	validation_0-rmse:0.14254
# [435]	validation_0-rmse:0.14254
# [436]	validation_0-rmse:0.14254
# [437]	validation_0-rmse:0.14253
# [438]	validation_0-rmse:0.14254
# [439]	validation_0-rmse:0.14253
# [440]	validation_0-rmse:0.14254
# [441]	validation_0-rmse:0.14253
# [442]	validation_0-rmse:0.14254
# [443]	validation_0-rmse:0.14253
# [444]	validation_0-rmse:0.14253
# [445]	validation_0-rmse:0.14222
# [446]	validation_0-rmse:0.14222
# [447]	validation_0-rmse:0.14222
# [448]	validation_0-rmse:0.14222
# [449]	validation_0-rmse:0.14222
# [450]	validation_0-rmse:0.14222
# [451]	validation_0-rmse:0.14222
# [452]	validation_0-rmse:0.14222
# [453]	validation_0-rmse:0.14222
# [454]	validation_0-rmse:0.14222
# [455]	validation_0-rmse:0.14222
# [456]	validation_0-rmse:0.14231
# [457]	validation_0-rmse:0.14231
# [458]	validation_0-rmse:0.14231
# [459]	validation_0-rmse:0.14231
# [460]	validation_0-rmse:0.14231
# [461]	validation_0-rmse:0.14231
# [462]	validation_0-rmse:0.14231
# [463]	validation_0-rmse:0.14231
# [464]	validation_0-rmse:0.14231
# [465]	validation_0-rmse:0.14231
# [466]	validation_0-rmse:0.14231
# [467]	validation_0-rmse:0.14231
# [468]	validation_0-rmse:0.14231
# [469]	validation_0-rmse:0.14231
# [470]	validation_0-rmse:0.14231
# [471]	validation_0-rmse:0.14231
# [472]	validation_0-rmse:0.14231
# [473]	validation_0-rmse:0.14231
# [474]	validation_0-rmse:0.14231
# [475]	validation_0-rmse:0.14231
# [476]	validation_0-rmse:0.14231
# [477]	validation_0-rmse:0.14231
# [478]	validation_0-rmse:0.14231
# [479]	validation_0-rmse:0.14231
# [480]	validation_0-rmse:0.14231
# [481]	validation_0-rmse:0.14231
# [482]	validation_0-rmse:0.14231
# [483]	validation_0-rmse:0.14231
# [484]	validation_0-rmse:0.14231
# [485]	validation_0-rmse:0.14231
# [486]	validation_0-rmse:0.14231
# [487]	validation_0-rmse:0.14231
# [488]	validation_0-rmse:0.14231
# [489]	validation_0-rmse:0.14231
# [490]	validation_0-rmse:0.14231
# [491]	validation_0-rmse:0.14231
# [492]	validation_0-rmse:0.14231
# [493]	validation_0-rmse:0.14231
# [494]	validation_0-rmse:0.14231
# [495]	validation_0-rmse:0.14231
# [496]	validation_0-rmse:0.14231
# [497]	validation_0-rmse:0.14231
# [498]	validation_0-rmse:0.14231
# [499]	validation_0-rmse:0.14232
# [500]	validation_0-rmse:0.14231
# [501]	validation_0-rmse:0.14232
# [502]	validation_0-rmse:0.14231
# [503]	validation_0-rmse:0.14231
# [504]	validation_0-rmse:0.14231
# [505]	validation_0-rmse:0.14231
# [506]	validation_0-rmse:0.14231
# [507]	validation_0-rmse:0.14231
# [508]	validation_0-rmse:0.14231
# [509]	validation_0-rmse:0.14231
# [510]	validation_0-rmse:0.14231
# [511]	validation_0-rmse:0.14231
# [512]	validation_0-rmse:0.14231
# [513]	validation_0-rmse:0.14231
# [514]	validation_0-rmse:0.14231
# [515]	validation_0-rmse:0.14231
# [516]	validation_0-rmse:0.14231
# [517]	validation_0-rmse:0.14231
# [518]	validation_0-rmse:0.14231
# [519]	validation_0-rmse:0.14231
# [520]	validation_0-rmse:0.14231
# [521]	validation_0-rmse:0.14231
# [522]	validation_0-rmse:0.14231
# [523]	validation_0-rmse:0.14231
# [524]	validation_0-rmse:0.14231
# [525]	validation_0-rmse:0.14231
# [526]	validation_0-rmse:0.14231
# [527]	validation_0-rmse:0.14231
# [528]	validation_0-rmse:0.14231
# [529]	validation_0-rmse:0.14231
# [530]	validation_0-rmse:0.14231
# [531]	validation_0-rmse:0.14231
# [532]	validation_0-rmse:0.14231
# [533]	validation_0-rmse:0.14231
# [534]	validation_0-rmse:0.14231
# [535]	validation_0-rmse:0.14231
# [536]	validation_0-rmse:0.14231
# [537]	validation_0-rmse:0.14231
# [538]	validation_0-rmse:0.14231
# [539]	validation_0-rmse:0.14231
# [540]	validation_0-rmse:0.14231
# [541]	validation_0-rmse:0.14231
# [542]	validation_0-rmse:0.14231
# [543]	validation_0-rmse:0.14231
# [544]	validation_0-rmse:0.14231
# [545]	validation_0-rmse:0.14231
# [546]	validation_0-rmse:0.14231
# [547]	validation_0-rmse:0.14231
# [548]	validation_0-rmse:0.14231
# [549]	validation_0-rmse:0.14231
# [550]	validation_0-rmse:0.14231
# [551]	validation_0-rmse:0.14231
# [552]	validation_0-rmse:0.14231
# [553]	validation_0-rmse:0.14231
# [554]	validation_0-rmse:0.14231
# [555]	validation_0-rmse:0.14231
# [556]	validation_0-rmse:0.14231
# [557]	validation_0-rmse:0.14231
# [558]	validation_0-rmse:0.14231
# [559]	validation_0-rmse:0.14231
# [560]	validation_0-rmse:0.14231
# [561]	validation_0-rmse:0.14231
# [562]	validation_0-rmse:0.14231
# [563]	validation_0-rmse:0.14231
# [564]	validation_0-rmse:0.14231
# [565]	validation_0-rmse:0.14231
# [566]	validation_0-rmse:0.14231
# [567]	validation_0-rmse:0.14231
# [568]	validation_0-rmse:0.14231
# [569]	validation_0-rmse:0.14231
# [570]	validation_0-rmse:0.14231
# [571]	validation_0-rmse:0.14231
# [572]	validation_0-rmse:0.14231
# [573]	validation_0-rmse:0.14231
# [574]	validation_0-rmse:0.14231
# [575]	validation_0-rmse:0.14231
# [576]	validation_0-rmse:0.14231
# [577]	validation_0-rmse:0.14231
# [578]	validation_0-rmse:0.14231
# [579]	validation_0-rmse:0.14231
# [580]	validation_0-rmse:0.14231
# [581]	validation_0-rmse:0.14231
# [582]	validation_0-rmse:0.14231
# [583]	validation_0-rmse:0.14231
# [584]	validation_0-rmse:0.14231
# [585]	validation_0-rmse:0.14231
# [586]	validation_0-rmse:0.14231
# [587]	validation_0-rmse:0.14231
# [588]	validation_0-rmse:0.14231
# [589]	validation_0-rmse:0.14231
# [590]	validation_0-rmse:0.14231
# [591]	validation_0-rmse:0.14231
# [592]	validation_0-rmse:0.14231
# [593]	validation_0-rmse:0.14231
# [594]	validation_0-rmse:0.14231
# [595]	validation_0-rmse:0.14231
# [596]	validation_0-rmse:0.14231
# [597]	validation_0-rmse:0.14231
# [598]	validation_0-rmse:0.14231
# [599]	validation_0-rmse:0.14231
# [600]	validation_0-rmse:0.14231
# [601]	validation_0-rmse:0.14231
# [602]	validation_0-rmse:0.14231
# [603]	validation_0-rmse:0.14231
# [604]	validation_0-rmse:0.14231
# [605]	validation_0-rmse:0.14231
# [606]	validation_0-rmse:0.14231
# [607]	validation_0-rmse:0.14231
# [608]	validation_0-rmse:0.14231
# [609]	validation_0-rmse:0.14231
# [610]	validation_0-rmse:0.14231
# [611]	validation_0-rmse:0.14231
# [612]	validation_0-rmse:0.14231
# [613]	validation_0-rmse:0.14231
# [614]	validation_0-rmse:0.14231
# [615]	validation_0-rmse:0.14231
# [616]	validation_0-rmse:0.14231
# [617]	validation_0-rmse:0.14231
# [618]	validation_0-rmse:0.14231
# [619]	validation_0-rmse:0.14231
# [620]	validation_0-rmse:0.14231
# [621]	validation_0-rmse:0.14231
# [622]	validation_0-rmse:0.14231
# [623]	validation_0-rmse:0.14231
# [624]	validation_0-rmse:0.14231
# [625]	validation_0-rmse:0.14231
# [626]	validation_0-rmse:0.14231
# [627]	validation_0-rmse:0.14231
# [628]	validation_0-rmse:0.14231
# [629]	validation_0-rmse:0.14231
# [630]	validation_0-rmse:0.14231
# [631]	validation_0-rmse:0.14231
# [632]	validation_0-rmse:0.14231
# [633]	validation_0-rmse:0.14231
# [634]	validation_0-rmse:0.14231
# [635]	validation_0-rmse:0.14231
# [636]	validation_0-rmse:0.14231
# [637]	validation_0-rmse:0.14231
# [638]	validation_0-rmse:0.14231
# [639]	validation_0-rmse:0.14231
# [640]	validation_0-rmse:0.14231
# [641]	validation_0-rmse:0.14231
# [642]	validation_0-rmse:0.14231
# [643]	validation_0-rmse:0.14232
# [644]	validation_0-rmse:0.14231
# [645]	validation_0-rmse:0.14231
# [646]	validation_0-rmse:0.14232
# [647]	validation_0-rmse:0.14231
# [648]	validation_0-rmse:0.14231
# [649]	validation_0-rmse:0.14231
# [650]	validation_0-rmse:0.14231
# [651]	validation_0-rmse:0.14231
# [652]	validation_0-rmse:0.14231
# [653]	validation_0-rmse:0.14231
# [654]	validation_0-rmse:0.14231
# [655]	validation_0-rmse:0.14231
# [656]	validation_0-rmse:0.14231
# [657]	validation_0-rmse:0.14231
# [658]	validation_0-rmse:0.14231
# [659]	validation_0-rmse:0.14231
# [660]	validation_0-rmse:0.14231
# [661]	validation_0-rmse:0.14231
# [662]	validation_0-rmse:0.14231
# [663]	validation_0-rmse:0.14231
# [664]	validation_0-rmse:0.14231
# [665]	validation_0-rmse:0.14231
# [666]	validation_0-rmse:0.14231
# [667]	validation_0-rmse:0.14231
# [668]	validation_0-rmse:0.14231
# [669]	validation_0-rmse:0.14231
# [670]	validation_0-rmse:0.14231
# [671]	validation_0-rmse:0.14231
# [672]	validation_0-rmse:0.14231
# [673]	validation_0-rmse:0.14232
# [674]	validation_0-rmse:0.14231
# [675]	validation_0-rmse:0.14231
# [676]	validation_0-rmse:0.14231
# [677]	validation_0-rmse:0.14231
# [678]	validation_0-rmse:0.14231
# [679]	validation_0-rmse:0.14231
# [680]	validation_0-rmse:0.14231
# [681]	validation_0-rmse:0.14231
# [682]	validation_0-rmse:0.14231
# [683]	validation_0-rmse:0.14231
# [684]	validation_0-rmse:0.14231
# [685]	validation_0-rmse:0.14231
# [686]	validation_0-rmse:0.14231
# [687]	validation_0-rmse:0.14231
# [688]	validation_0-rmse:0.14231
# [689]	validation_0-rmse:0.14231
# [690]	validation_0-rmse:0.14231
# [691]	validation_0-rmse:0.14231
# [692]	validation_0-rmse:0.14231
# [693]	validation_0-rmse:0.14231
# [694]	validation_0-rmse:0.14231
# [695]	validation_0-rmse:0.14231
# [696]	validation_0-rmse:0.14231
# [697]	validation_0-rmse:0.14231
# [698]	validation_0-rmse:0.14231
# [699]	validation_0-rmse:0.14231
# [700]	validation_0-rmse:0.14231
# [701]	validation_0-rmse:0.14231
# [702]	validation_0-rmse:0.14231
# [703]	validation_0-rmse:0.14231
# [704]	validation_0-rmse:0.14231
# [705]	validation_0-rmse:0.14231
# [706]	validation_0-rmse:0.14231
# [707]	validation_0-rmse:0.14231
# [708]	validation_0-rmse:0.14231
# [709]	validation_0-rmse:0.14231
# [710]	validation_0-rmse:0.14231
# [711]	validation_0-rmse:0.14231
# [712]	validation_0-rmse:0.14231
# [713]	validation_0-rmse:0.14231
# [714]	validation_0-rmse:0.14231
# [715]	validation_0-rmse:0.14231
# [716]	validation_0-rmse:0.14231
# [717]	validation_0-rmse:0.14231
# [718]	validation_0-rmse:0.14231
# [719]	validation_0-rmse:0.14231
# [720]	validation_0-rmse:0.14231
# [721]	validation_0-rmse:0.14231
# [722]	validation_0-rmse:0.14231
# [723]	validation_0-rmse:0.14231
# [724]	validation_0-rmse:0.14231
# [725]	validation_0-rmse:0.14231
# [726]	validation_0-rmse:0.14231
# [727]	validation_0-rmse:0.14231
# [728]	validation_0-rmse:0.14231
# [729]	validation_0-rmse:0.14231
# [730]	validation_0-rmse:0.14231
# [731]	validation_0-rmse:0.14231
# [732]	validation_0-rmse:0.14231
# [733]	validation_0-rmse:0.14231
# [734]	validation_0-rmse:0.14231
# [735]	validation_0-rmse:0.14231
# [736]	validation_0-rmse:0.14231
# [737]	validation_0-rmse:0.14231
# [738]	validation_0-rmse:0.14231
# [739]	validation_0-rmse:0.14231
# [740]	validation_0-rmse:0.14231
# [741]	validation_0-rmse:0.14231
# [742]	validation_0-rmse:0.14231
# [743]	validation_0-rmse:0.14231
# [744]	validation_0-rmse:0.14231
# [745]	validation_0-rmse:0.14231
# [746]	validation_0-rmse:0.14231
# [747]	validation_0-rmse:0.14231
# [748]	validation_0-rmse:0.14231
# [749]	validation_0-rmse:0.14231
# [750]	validation_0-rmse:0.14231
# [751]	validation_0-rmse:0.14231
# [752]	validation_0-rmse:0.14231
# [753]	validation_0-rmse:0.14231
# [754]	validation_0-rmse:0.14231
# [755]	validation_0-rmse:0.14231
# [756]	validation_0-rmse:0.14231
# [757]	validation_0-rmse:0.14231
# [758]	validation_0-rmse:0.14231
# [759]	validation_0-rmse:0.14231
# [760]	validation_0-rmse:0.14231
# [761]	validation_0-rmse:0.14231
# [762]	validation_0-rmse:0.14231
# [763]	validation_0-rmse:0.14231
# [764]	validation_0-rmse:0.14231
# [765]	validation_0-rmse:0.14231
# [766]	validation_0-rmse:0.14231
# [767]	validation_0-rmse:0.14231
# [768]	validation_0-rmse:0.14231
# [769]	validation_0-rmse:0.14231
# [770]	validation_0-rmse:0.14231
# [771]	validation_0-rmse:0.14231
# [772]	validation_0-rmse:0.14231
# [773]	validation_0-rmse:0.14231
# [774]	validation_0-rmse:0.14231
# [775]	validation_0-rmse:0.14231
# [776]	validation_0-rmse:0.14231
# [777]	validation_0-rmse:0.14231
# [778]	validation_0-rmse:0.14231
# [779]	validation_0-rmse:0.14231
# [780]	validation_0-rmse:0.14231
# [781]	validation_0-rmse:0.14231
# [782]	validation_0-rmse:0.14231
# [783]	validation_0-rmse:0.14231
# [784]	validation_0-rmse:0.14231
# [785]	validation_0-rmse:0.14231
# [786]	validation_0-rmse:0.14231
# [787]	validation_0-rmse:0.14231
# [788]	validation_0-rmse:0.14231
# [789]	validation_0-rmse:0.14232
# [790]	validation_0-rmse:0.14231
# [791]	validation_0-rmse:0.14231
# [792]	validation_0-rmse:0.14231
# [793]	validation_0-rmse:0.14231
# [794]	validation_0-rmse:0.14231
# [795]	validation_0-rmse:0.14231
# [796]	validation_0-rmse:0.14231
# [797]	validation_0-rmse:0.14231
# [798]	validation_0-rmse:0.14231
# [799]	validation_0-rmse:0.14231
# [800]	validation_0-rmse:0.14231
# [801]	validation_0-rmse:0.14231
# [802]	validation_0-rmse:0.14231
# [803]	validation_0-rmse:0.14231
# [804]	validation_0-rmse:0.14231
# [805]	validation_0-rmse:0.14231
# [806]	validation_0-rmse:0.14231
# [807]	validation_0-rmse:0.14231
# [808]	validation_0-rmse:0.14231
# [809]	validation_0-rmse:0.14231
# [810]	validation_0-rmse:0.14232
# [811]	validation_0-rmse:0.14231
# [812]	validation_0-rmse:0.14231
# [813]	validation_0-rmse:0.14231
# [814]	validation_0-rmse:0.14231
# [815]	validation_0-rmse:0.14231
# [816]	validation_0-rmse:0.14232
# [817]	validation_0-rmse:0.14232
# [818]	validation_0-rmse:0.14231
# [819]	validation_0-rmse:0.14231
# [820]	validation_0-rmse:0.14231
# [821]	validation_0-rmse:0.14231
# [822]	validation_0-rmse:0.14231
# [823]	validation_0-rmse:0.14231
# [824]	validation_0-rmse:0.14222
# [825]	validation_0-rmse:0.14222
# [826]	validation_0-rmse:0.14222
# [827]	validation_0-rmse:0.14222
# [828]	validation_0-rmse:0.14222
# [829]	validation_0-rmse:0.14222
# RMSE :  0.142222

# %%
print("score train :",xgb_r.score(X_train, y_train))
print("score test :", xgb_r.score(X_test, y_test))
# Out:
# score train : 0.9527804095581764
# score test : 0.8730240817220112

# %%
#pred = xgb_r.predict(pca.transform(df_test))
pred = xgb_r.predict(df_test)

df_pred = pd.DataFrame(np.expm1(pred), columns=['SalePrice'])
df_pred.head()
# Out:
#        SalePrice
# 0  135217.687500
# 1  159440.156250
# 2  171187.234375
# 3  181970.375000
# 4  204164.359375

# %%
df_pred = df_test_Id.join(df_pred)
df_pred.to_csv('./submission/model_xgb_r.csv', index=False)
